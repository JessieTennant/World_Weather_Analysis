# %%
pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559704 sha256=7bdab225b0118aa272d9a58fe79cdb8ebb852d6677ea0c4c005cb5b931c32dce
#   Stored in directory: c:\users\ichib\appdata\local\pip\cache\wheels\6d\df\5e\ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=275dc42e1f091b28df7e3efd5decc820

# %%
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Run an API request for each of the cities.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | biak
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | guozhen
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | pires do rio
# Processing Record 10 of Set 1 | santa helena
# Processing Record 11 of Set 1 | isangel
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | codrington
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | ajaccio
# Processing Record 19 of Set 1 | nauen
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | faya
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | kamenka
# Processing Record 27 of Set 1 | saint-georges
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | iralaya
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | henties bay
# Processing Record 36 of Set 1 | constitucion
# Processing Record 37 of Set 1 | rognan
# Processing Record 38 of Set 1 | nowe miasto lubawskie
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | byron bay
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | resistencia
# Processing Record 44 of Set 1 | khakhea
# Processing Record 45 of Set 1 | port-gentil
# Processing Record 46 of Set 1 | pisco
# Processing Record 47 of Set 1 | laguna
# Processing Record 48 of Set 1 | itoman
# Processing Record 49 of Set 1 | nabire
# Processing Record 50 of Set 1 | northam
# Processing Record 1 of Set 2 | lovozero
# Processing Record 2 of Set 2 | abu samrah
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | saint anthony
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | taltal
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | tura
# Processing Record 11 of Set 2 | charters towers
# Processing Record 12 of Set 2 | lodingen
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | lagos
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | mokrous
# Processing Record 18 of Set 2 | emborion
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | husavik
# Processing Record 24 of Set 2 | umkomaas
# Processing Record 25 of Set 2 | necochea
# Processing Record 26 of Set 2 | bonthe
# Processing Record 27 of Set 2 | navahrudak
# Processing Record 28 of Set 2 | mandalgovi
# Processing Record 29 of Set 2 | tautira
# Processing Record 30 of Set 2 | hamilton
# Processing Record 31 of Set 2 | portland
# Processing Record 32 of Set 2 | labuhan
# Processing Record 33 of Set 2 | havelock
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | busselton
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | broome
# Processing Record 39 of Set 2 | dubbo
# Processing Record 40 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 2 | suoyarvi
# Processing Record 42 of Set 2 | puri
# Processing Record 43 of Set 2 | outlook
# Processing Record 44 of Set 2 | muisne
# Processing Record 45 of Set 2 | ha giang
# Processing Record 46 of Set 2 | praid
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | lobito
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | saint-francois
# Processing Record 1 of Set 3 | burntwood
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | mataura
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | thaba-tseka
# Processing Record 6 of Set 3 | shimoda
# Processing Record 7 of Set 3 | grafton
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | songkhla
# Processing Record 11 of Set 3 | praia da vitoria
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 3 | grand gaube
# Processing Record 15 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 3 | mananjary
# Processing Record 17 of Set 3 | saint-pierre
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | benguela
# Processing Record 20 of Set 3 | pontal do parana
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | guane
# Processing Record 23 of Set 3 | san rafael
# Processing Record 24 of Set 3 | acapulco
# Processing Record 25 of Set 3 | veraval
# Processing Record 26 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | humaita
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | morondava
# Processing Record 31 of Set 3 | pallasovka
# Processing Record 32 of Set 3 | roald
# Processing Record 33 of Set 3 | brockville
# Processing Record 34 of Set 3 | port blair
# Processing Record 35 of Set 3 | margate
# Processing Record 36 of Set 3 | ginir
# Processing Record 37 of Set 3 | ende
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | ebeltoft
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | payakumbuh
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | lagoa
# Processing Record 44 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 3 | egvekinot
# Processing Record 46 of Set 3 | asau
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | peoria
# Processing Record 50 of Set 3 | maceio
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | sarkand
# Processing Record 3 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 4 | hoddesdon
# Processing Record 5 of Set 4 | acarau
# Processing Record 6 of Set 4 | seoul
# Processing Record 7 of Set 4 | saint george
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | narsaq
# Processing Record 11 of Set 4 | adrar
# Processing Record 12 of Set 4 | naze
# Processing Record 13 of Set 4 | berezyne
# Processing Record 14 of Set 4 | muriwai beach
# Processing Record 15 of Set 4 | whitehorse
# Processing Record 16 of Set 4 | ambilobe
# Processing Record 17 of Set 4 | muroto
# Processing Record 18 of Set 4 | hambantota
# Processing Record 19 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 20 of Set 4 | noumea
# Processing Record 21 of Set 4 | yatou
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | mantua
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | grindavik
# Processing Record 27 of Set 4 | meulaboh
# Processing Record 28 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 4 | lloydminster
# Processing Record 30 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 4 | farap
# Processing Record 32 of Set 4 | kudahuvadhoo
# Processing Record 33 of Set 4 | kenai
# Processing Record 34 of Set 4 | champasak
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | srednekolymsk
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | kismayo
# Processing Record 39 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 4 | nouadhibou
# Processing Record 41 of Set 4 | sakit
# Processing Record 42 of Set 4 | chicama
# Processing Record 43 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 4 | stepnogorsk
# Processing Record 45 of Set 4 | sambava
# Processing Record 46 of Set 4 | colinas
# Processing Record 47 of Set 4 | airai
# Processing Record 48 of Set 4 | nemuro
# Processing Record 49 of Set 4 | kawhia
# Processing Record 50 of Set 4 | ponta do sol
# Processing Record 1 of Set 5 | paciran
# Processing Record 2 of Set 5 | upernavik
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | ciudad bolivar
# Processing Record 5 of Set 5 | belfast
# Processing Record 6 of Set 5 | karratha
# Processing Record 7 of Set 5 | ostrovnoy
# Processing Record 8 of Set 5 | inta
# Processing Record 9 of Set 5 | nome
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | jeremie
# Processing Record 12 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 5 | srandakan
# Processing Record 14 of Set 5 | dhidhdhoo
# Processing Record 15 of Set 5 | kavieng
# Processing Record 16 of Set 5 | alihe
# Processing Record 17 of Set 5 | port hedland
# Processing Record 18 of Set 5 | puerto boyaca
# Processing Record 19 of Set 5 | diffa
# Processing Record 20 of Set 5 | sheboygan
# Processing Record 21 of Set 5 | pyaozerskiy
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | maryville
# Processing Record 24 of Set 5 | gweta
# Processing Record 25 of Set 5 | takoradi
# Processing Record 26 of Set 5 | teguise
# Processing Record 27 of Set 5 | lebu
# Processing Record 28 of Set 5 | buala
# Processing Record 29 of Set 5 | los llanos de aridane
# Processing Record 30 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 5 | san policarpo
# Processing Record 32 of Set 5 | sterling
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | avarua
# Processing Record 35 of Set 5 | coari
# Processing Record 36 of Set 5 | okhotsk
# Processing Record 37 of Set 5 | batemans bay
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | kourou
# Processing Record 40 of Set 5 | aklavik
# Processing Record 41 of Set 5 | katsuura
# Processing Record 42 of Set 5 | gaoua
# Processing Record 43 of Set 5 | samarai
# Processing Record 44 of Set 5 | haines junction
# Processing Record 45 of Set 5 | yar-sale
# Processing Record 46 of Set 5 | barguzin
# Processing Record 47 of Set 5 | lasa
# Processing Record 48 of Set 5 | lanzhou
# Processing Record 49 of Set 5 | iskateley
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | lodja
# Processing Record 4 of Set 6 | capanema
# Processing Record 5 of Set 6 | miranda
# Processing Record 6 of Set 6 | hay river
# Processing Record 7 of Set 6 | dzhebariki-khaya
# Processing Record 8 of Set 6 | maragogi
# Processing Record 9 of Set 6 | novyy urengoy
# Processing Record 10 of Set 6 | brainerd
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | nikolskoye
# Processing Record 13 of Set 6 | torbay
# Processing Record 14 of Set 6 | souillac
# Processing Record 15 of Set 6 | salekhard
# Processing Record 16 of Set 6 | bahia blanca
# Processing Record 17 of Set 6 | valdivia
# Processing Record 18 of Set 6 | kendari
# Processing Record 19 of Set 6 | kaitangata
# Processing Record 20 of Set 6 | grave
# Processing Record 21 of Set 6 | le pradet
# Processing Record 22 of Set 6 | kaoma
# Processing Record 23 of Set 6 | gunnedah
# Processing Record 24 of Set 6 | aktash
# Processing Record 25 of Set 6 | mukhen
# Processing Record 26 of Set 6 | kununurra
# Processing Record 27 of Set 6 | beruwala
# Processing Record 28 of Set 6 | quatre cocos
# Processing Record 29 of Set 6 | tymovskoye
# Processing Record 30 of Set 6 | cidreira
# Processing Record 31 of Set 6 | mangan
# Processing Record 32 of Set 6 | yegorlykskaya
# Processing Record 33 of Set 6 | dukat
# Processing Record 34 of Set 6 | alcantara
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | kieta
# Processing Record 37 of Set 6 | bubaque
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | cabedelo
# Processing Record 40 of Set 6 | arman
# Processing Record 41 of Set 6 | camopi
# Processing Record 42 of Set 6 | nuuk
# Processing Record 43 of Set 6 | falkenberg
# Processing Record 44 of Set 6 | tarauaca
# Processing Record 45 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 6 | dingle
# Processing Record 47 of Set 6 | horta
# Processing Record 48 of Set 6 | springfield
# Processing Record 49 of Set 6 | le vauclin
# Processing Record 50 of Set 6 | sjovegan
# Processing Record 1 of Set 7 | half moon bay
# Processing Record 2 of Set 7 | kidal
# Processing Record 3 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 4 of Set 7 | borogontsy
# Processing Record 5 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 6 of Set 7 | qasigiannguit
# Processing Record 7 of Set 7 | babaeski
# Processing Record 8 of Set 7 | koltsovo
# Processing Record 9 of Set 7 | guamuchil
# Processing Record 10 of Set 7 | kavaratti
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | quballat
# Processing Record 13 of Set 7 | zavodouspenskoye
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | zambezi
# Processing Record 16 of Set 7 | mount isa
# Processing Record 17 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 7 | tadine
# Processing Record 19 of Set 7 | bilibino
# Processing Record 20 of Set 7 | mineiros
# Processing Record 21 of Set 7 | hasaki
# Processing Record 22 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 7 | leningradskiy
# Processing Record 24 of Set 7 | lompoc
# Processing Record 25 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 7 | hofn
# Processing Record 27 of Set 7 | isla mujeres
# Processing Record 28 of Set 7 | champerico
# Processing Record 29 of Set 7 | kuusamo
# Processing Record 30 of Set 7 | flinders
# Processing Record 31 of Set 7 | bereda
# Processing Record 32 of Set 7 | quesnel
# Processing Record 33 of Set 7 | nara
# Processing Record 34 of Set 7 | carutapera
# Processing Record 35 of Set 7 | launceston
# Processing Record 36 of Set 7 | sistranda
# Processing Record 37 of Set 7 | buenos aires
# Processing Record 38 of Set 7 | burica
# City not found. Skipping...
# Processing Record 39 of Set 7 | general roca
# Processing Record 40 of Set 7 | prestice
# Processing Record 41 of Set 7 | bonavista
# Processing Record 42 of Set 7 | nuqui
# Processing Record 43 of Set 7 | tual
# Processing Record 44 of Set 7 | kaya
# Processing Record 45 of Set 7 | louis trichardt
# Processing Record 46 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 7 | orlik
# Processing Record 48 of Set 7 | anadyr
# Processing Record 49 of Set 7 | bac lieu
# Processing Record 50 of Set 7 | tokonou
# Processing Record 1 of Set 8 | belyy
# Processing Record 2 of Set 8 | hovd
# Processing Record 3 of Set 8 | ust-omchug
# Processing Record 4 of Set 8 | namibe
# Processing Record 5 of Set 8 | sadri
# Processing Record 6 of Set 8 | pedasi
# Processing Record 7 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 8 of Set 8 | inhambane
# Processing Record 9 of Set 8 | port moresby
# Processing Record 10 of Set 8 | kirkwall
# Processing Record 11 of Set 8 | innisfail
# Processing Record 12 of Set 8 | tabou
# Processing Record 13 of Set 8 | leshukonskoye
# Processing Record 14 of Set 8 | ketchikan
# Processing Record 15 of Set 8 | dalbandin
# Processing Record 16 of Set 8 | xining
# Processing Record 17 of Set 8 | cabra
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | westport
# Processing Record 20 of Set 8 | boulsa
# Processing Record 21 of Set 8 | kulhudhuffushi
# Processing Record 22 of Set 8 | zhigansk
# Processing Record 23 of Set 8 | cartagena
# Processing Record 24 of Set 8 | atlantic city
# Processing Record 25 of Set 8 | kimbe
# Processing Record 26 of Set 8 | cherskiy
# Processing Record 27 of Set 8 | kitimat
# Processing Record 28 of Set 8 | riyadh
# Processing Record 29 of Set 8 | ovalle
# Processing Record 30 of Set 8 | blagoyevo
# Processing Record 31 of Set 8 | vikhorevka
# Processing Record 32 of Set 8 | kruisfontein
# Processing Record 33 of Set 8 | kahului
# Processing Record 34 of Set 8 | marfino
# Processing Record 35 of Set 8 | yen bai
# Processing Record 36 of Set 8 | qingdao
# Processing Record 37 of Set 8 | bongandanga
# Processing Record 38 of Set 8 | gualeguaychu
# Processing Record 39 of Set 8 | hoquiam
# Processing Record 40 of Set 8 | yugorsk
# Processing Record 41 of Set 8 | nioro
# Processing Record 42 of Set 8 | wakefield
# Processing Record 43 of Set 8 | nieuw amsterdam
# Processing Record 44 of Set 8 | sinnamary
# Processing Record 45 of Set 8 | eureka
# Processing Record 46 of Set 8 | kefamenanu
# Processing Record 47 of Set 8 | staryy nadym
# Processing Record 48 of Set 8 | daru
# Processing Record 49 of Set 8 | garhakota
# Processing Record 50 of Set 8 | sao joao da barra
# Processing Record 1 of Set 9 | bima
# Processing Record 2 of Set 9 | bengkulu
# Processing Record 3 of Set 9 | obsharovka
# Processing Record 4 of Set 9 | chara
# Processing Record 5 of Set 9 | kingaroy
# Processing Record 6 of Set 9 | beyneu
# Processing Record 7 of Set 9 | araouane
# Processing Record 8 of Set 9 | tarnogskiy gorodok
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | rhyl
# Processing Record 11 of Set 9 | george
# Processing Record 12 of Set 9 | putai
# Processing Record 13 of Set 9 | glen allen
# Processing Record 14 of Set 9 | namatanai
# Processing Record 15 of Set 9 | faanui
# Processing Record 16 of Set 9 | celestun
# Processing Record 17 of Set 9 | padang
# Processing Record 18 of Set 9 | jiangyou
# Processing Record 19 of Set 9 | langarud
# Processing Record 20 of Set 9 | olafsvik
# Processing Record 21 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 22 of Set 9 | saint-augustin
# Processing Record 23 of Set 9 | ondjiva
# Processing Record 24 of Set 9 | udachnyy
# Processing Record 25 of Set 9 | moussoro
# Processing Record 26 of Set 9 | bambous virieux
# Processing Record 27 of Set 9 | puerto leguizamo
# Processing Record 28 of Set 9 | brae
# Processing Record 29 of Set 9 | rovaniemi
# Processing Record 30 of Set 9 | marsh harbour
# Processing Record 31 of Set 9 | misratah
# Processing Record 32 of Set 9 | fairbanks
# Processing Record 33 of Set 9 | taunggyi
# Processing Record 34 of Set 9 | ouango
# Processing Record 35 of Set 9 | wuwei
# Processing Record 36 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 37 of Set 9 | shache
# Processing Record 38 of Set 9 | bani walid
# Processing Record 39 of Set 9 | tchollire
# Processing Record 40 of Set 9 | berlevag
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | umm lajj
# Processing Record 43 of Set 9 | vostok
# Processing Record 44 of Set 9 | creel
# Processing Record 45 of Set 9 | dalvik
# Processing Record 46 of Set 9 | bonfim
# Processing Record 47 of Set 9 | albanel
# Processing Record 48 of Set 9 | gambela
# Processing Record 49 of Set 9 | palmer
# Processing Record 50 of Set 9 | huejuquilla el alto
# Processing Record 1 of Set 10 | port jervis
# Processing Record 2 of Set 10 | san luis rio colorado
# Processing Record 3 of Set 10 | malakal
# Processing Record 4 of Set 10 | kargopol
# Processing Record 5 of Set 10 | arroio dos ratos
# Processing Record 6 of Set 10 | tongchuan
# Processing Record 7 of Set 10 | paita
# Processing Record 8 of Set 10 | mitsamiouli
# Processing Record 9 of Set 10 | bang racham
# Processing Record 10 of Set 10 | bargteheide
# Processing Record 11 of Set 10 | peleduy
# Processing Record 12 of Set 10 | maniitsoq
# Processing Record 13 of Set 10 | kisangani
# Processing Record 14 of Set 10 | moron
# Processing Record 15 of Set 10 | marrakesh
# Processing Record 16 of Set 10 | hokitika
# Processing Record 17 of Set 10 | forchheim
# Processing Record 18 of Set 10 | rawson
# Processing Record 19 of Set 10 | puerto padre
# Processing Record 20 of Set 10 | sola
# Processing Record 21 of Set 10 | tshane
# Processing Record 22 of Set 10 | paamiut
# Processing Record 23 of Set 10 | touros
# Processing Record 24 of Set 10 | port said
# Processing Record 25 of Set 10 | vadnagar
# Processing Record 26 of Set 10 | bodden town
# Processing Record 27 of Set 10 | port hardy
# Processing Record 28 of Set 10 | kupang
# Processing Record 29 of Set 10 | uni
# Processing Record 30 of Set 10 | cravo norte
# Processing Record 31 of Set 10 | luganville
# Processing Record 32 of Set 10 | mount pleasant
# Processing Record 33 of Set 10 | berbera
# Processing Record 34 of Set 10 | vestmannaeyjar
# Processing Record 35 of Set 10 | coquimbo
# Processing Record 36 of Set 10 | poum
# Processing Record 37 of Set 10 | oistins
# Processing Record 38 of Set 10 | wagga wagga
# Processing Record 39 of Set 10 | mvuma
# Processing Record 40 of Set 10 | jorochito
# Processing Record 41 of Set 10 | sulangan
# Processing Record 42 of Set 10 | paris
# Processing Record 43 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 10 | krasnovishersk
# Processing Record 45 of Set 10 | santa fe
# Processing Record 46 of Set 10 | bundaberg
# Processing Record 47 of Set 10 | okakarara
# Processing Record 48 of Set 10 | christchurch
# Processing Record 49 of Set 10 | ko samui
# Processing Record 50 of Set 10 | nelson bay
# Processing Record 1 of Set 11 | shingu
# Processing Record 2 of Set 11 | wanaka
# Processing Record 3 of Set 11 | karasjok
# Processing Record 4 of Set 11 | mae ramat
# Processing Record 5 of Set 11 | luwuk
# Processing Record 6 of Set 11 | igarka
# Processing Record 7 of Set 11 | krasnotorka
# Processing Record 8 of Set 11 | wuxue
# Processing Record 9 of Set 11 | imbituba
# Processing Record 10 of Set 11 | kohlu
# Processing Record 11 of Set 11 | lima
# Processing Record 12 of Set 11 | balkanabat
# Processing Record 13 of Set 11 | severo-kurilsk
# Processing Record 14 of Set 11 | la sarre
# Processing Record 15 of Set 11 | novyy urgal
# Processing Record 16 of Set 11 | paramonga
# Processing Record 17 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 11 | challapata
# Processing Record 19 of Set 11 | jaciara
# Processing Record 20 of Set 11 | camacha
# Processing Record 21 of Set 11 | victoria
# Processing Record 22 of Set 11 | guaruja
# Processing Record 23 of Set 11 | beringovskiy
# Processing Record 24 of Set 11 | pedreiras
# Processing Record 25 of Set 11 | sheridan
# Processing Record 26 of Set 11 | sangueya
# Processing Record 27 of Set 11 | odweyne
# Processing Record 28 of Set 11 | ancud
# Processing Record 29 of Set 11 | walvis bay
# Processing Record 30 of Set 11 | guanica
# Processing Record 31 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 11 | sur
# Processing Record 33 of Set 11 | wamba
# Processing Record 34 of Set 11 | chumikan
# Processing Record 35 of Set 11 | newport
# Processing Record 36 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 11 | gasa
# Processing Record 38 of Set 11 | trincomalee
# Processing Record 39 of Set 11 | rorvik
# Processing Record 40 of Set 11 | ola
# Processing Record 41 of Set 11 | wote
# Processing Record 42 of Set 11 | suez
# Processing Record 43 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 11 | williams lake
# Processing Record 46 of Set 11 | galle
# Processing Record 47 of Set 11 | ilam
# Processing Record 48 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 11 | la palma
# Processing Record 50 of Set 11 | stamford
# Processing Record 1 of Set 12 | kamen-rybolov
# Processing Record 2 of Set 12 | vallenar
# Processing Record 3 of Set 12 | villa union
# Processing Record 4 of Set 12 | kajaani
# Processing Record 5 of Set 12 | cap malheureux
# Processing Record 6 of Set 12 | ladario
# Processing Record 7 of Set 12 | coolum beach
# Processing Record 8 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 12 | thinadhoo
# Processing Record 10 of Set 12 | beziers
# Processing Record 11 of Set 12 | mucurapo
# Processing Record 12 of Set 12 | totness
# Processing Record 13 of Set 12 | siirt
# Processing Record 14 of Set 12 | alta floresta
# Processing Record 15 of Set 12 | bara
# Processing Record 16 of Set 12 | narasannapeta
# Processing Record 17 of Set 12 | sabang
# Processing Record 18 of Set 12 | pathankot
# Processing Record 19 of Set 12 | raudeberg
# Processing Record 20 of Set 12 | bismarck
# Processing Record 21 of Set 12 | ilebo
# Processing Record 22 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 23 of Set 12 | brigantine
# Processing Record 24 of Set 12 | werda
# Processing Record 25 of Set 12 | griffin
# Processing Record 26 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 12 | sulzbach-rosenberg
# Processing Record 28 of Set 12 | kharitonovo
# Processing Record 29 of Set 12 | alpena
# Processing Record 30 of Set 12 | birecik
# Processing Record 31 of Set 12 | iqaluit
# Processing Record 32 of Set 12 | bocaranga
# City not found. Skipping...
# Processing Record 33 of Set 12 | nantucket
# Processing Record 34 of Set 12 | ossora
# Processing Record 35 of Set 12 | vila franca do campo
# Processing Record 36 of Set 12 | laramie
# Processing Record 37 of Set 12 | juneau
# Processing Record 38 of Set 12 | bukama
# Processing Record 39 of Set 12 | kirakira
# Processing Record 40 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 12 | berdigestyakh
# Processing Record 42 of Set 12 | primore
# City not found. Skipping...
# Processing Record 43 of Set 12 | ambulu
# Processing Record 44 of Set 12 | tommot
# Processing Record 45 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 46 of Set 12 | vila velha
# Processing Record 47 of Set 12 | baruun-urt
# Processing Record 48 of Set 12 | gillette
# Processing Record 49 of Set 12 | vardo
# Processing Record 50 of Set 12 | maningrida
# Processing Record 1 of Set 13 | beloha
# Processing Record 2 of Set 13 | akyab
# Processing Record 3 of Set 13 | avera
# Processing Record 4 of Set 13 | carauari
# Processing Record 5 of Set 13 | sao joao del rei
# Processing Record 6 of Set 13 | la baule-escoublac
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0          Biak      ID  2021-02-07 21:25:04  -0.9131  122.8766     77.13
# 1      Saldanha      ZA  2021-02-07 21:25:04 -33.0117   17.9442     62.60
# 2  Norman Wells      CA  2021-02-07 21:25:04  65.2820 -126.8329    -20.20
# 3  Punta Arenas      CL  2021-02-07 21:25:05 -53.1500  -70.9167     73.40
# 4       Guozhen      CN  2021-02-07 21:25:05  34.3659  107.3590     40.14
# 5      Hermanus      ZA  2021-02-07 21:25:05 -34.4187   19.2345     64.99
# 6       Ushuaia      AR  2021-02-07 21:21:02 -54.8000  -68.3000     62.60
# 7       Rikitea      PF  2021-02-07 21:25:06 -23.1203 -134.9692     77.40
# 8  Pires Do Rio      BR  2021-02-07 21:25:06 -17.2997  -48.2794     72.19
# 9  Santa Helena      BR  2021-02-07 21:25:06  -2.2311  -45.3000     83.82
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        79         100        2.01     overcast clouds
# 1        72           0       14.97           clear sky
# 2        69          40        3.44    scattered clouds
# 3        21           0       14.97           clear sky
# 4        61           0        1.83           clear sky
# 5        78           8        4.88           clear sky
# 6        55          75        6.91       broken clouds
# 7        73          97       13.04     overcast clouds
# 8        90         100        7.25     overcast clouds
# 9        64          23        5.08          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
